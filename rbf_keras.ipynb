# %% [markdown]
# <a href="https://colab.research.google.com/github/Masoud0389/Steady_State/blob/main/rbf_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install git+https://github.com/Kaggle/learntools.git

# %%
# Setup plotting
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system

from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# WARNING:root:Ignoring repeated attempt to bind to globals

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, normalize
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
import warnings
import numpy as np
warnings.filterwarnings('ignore')
data = pd.read_csv('DATASET1.csv')
#data.info()

# %%
data.head(5)
# Out:
#    V1       V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1  0.99833  0.99057  0.98682  0.98319  0.97557  0.97521  0.97276  0.97097
# 1   1  0.99834  0.99066  0.98695  0.98336  0.97583  0.97549  0.97307  0.97131
# 2   1  0.99834  0.99066  0.98695  0.98335  0.97582  0.97548  0.97306  0.97130
# 3   1  0.99832  0.99056  0.98681  0.98317  0.97554  0.97518  0.97272  0.97093
# 4   1  0.99829  0.99037  0.98653  0.98281  0.97497  0.97457  0.97207  0.97020
#
#        V10  ...      V28      V29      V30      V31      V32      V33  \
# 0  0.96949  ...  0.96900  0.96591  0.96443  0.96483  0.96541  0.96693
# 1  0.96986  ...  0.96935  0.96630  0.96484  0.96527  0.96584  0.96737
# 2  0.96985  ...  0.96933  0.96629  0.96483  0.96525  0.96583  0.96736
# 3  0.96944  ...  0.96896  0.96586  0.96438  0.96478  0.96536  0.96688
# 4  0.96865  ...  0.96822  0.96503  0.96351  0.96387  0.96443  0.96596
#
#       load  weakdays  season  label
# 0  0.67977         1       1      0
# 1  0.67443         1       1      0
# 2  0.67463         1       1      0
# 3  0.68036         1       1      0
# 4  0.69162         1       1      0
#
# [5 rows x 37 columns]

# %%
#data.isna().sum()

# %%
#data.season.value_counts()/96

# %%
g = sns.countplot(data['season'])
g.set_xticklabels(['Winter','Spring', 'Summer', 'Fall'])
plt.show()

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
X = StandardScaler().fit_transform(X)
X = normalize(X, norm="max")

# %%
# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.7)
input_shape = [X_train.shape[1]]

# %%
from tensorflow import keras
from keras.layers import Layer, Dense, Flatten
from keras import backend as K
from keras import layers
from keras.models import Sequential
from keras.losses import binary_crossentropy


class RBFLayer(Layer):
    def __init__(self, units, gamma, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.units = units
        self.gamma = K.cast_to_floatx(gamma)

    def build(self, input_shape):
        self.mu = self.add_weight(name='mu',
                                  shape=(int(input_shape[1]), self.units),
                                  initializer='uniform',
                                  trainable=True)
        super(RBFLayer, self).build(input_shape)

    def call(self, inputs):
        diff = K.expand_dims(inputs) - self.mu
        l2 = K.sum(K.pow(diff,2), axis=1)
        res = K.exp(-1 * self.gamma * l2)
        return res

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.units)
model = Sequential()
model.add(Flatten(input_shape=(36,)))
model.add(Dense(128, activation='relu'))
model.add(RBFLayer(80, 0.1))
model.add(RBFLayer(5, 0.05))
model.add(RBFLayer(2, 0.05))
model.add(Dense(1, activation='sigmoid', name='foo'))

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.0001,
    restore_best_weights=True,
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/200
# 96/96 [==============================] - 3s 24ms/step - loss: 0.6934 - binary_accuracy: 0.5000 - val_loss: 0.6872 - val_binary_accuracy: 0.5000
# Epoch 2/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.6845 - binary_accuracy: 0.5873 - val_loss: 0.6825 - val_binary_accuracy: 0.6156
# Epoch 3/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.6802 - binary_accuracy: 0.6197 - val_loss: 0.6783 - val_binary_accuracy: 0.6161
# Epoch 4/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.6758 - binary_accuracy: 0.6195 - val_loss: 0.6740 - val_binary_accuracy: 0.6172
# Epoch 5/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.6715 - binary_accuracy: 0.6190 - val_loss: 0.6699 - val_binary_accuracy: 0.6184
# Epoch 6/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.6491 - binary_accuracy: 0.6970 - val_loss: 0.6361 - val_binary_accuracy: 0.7297
# Epoch 7/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.6301 - binary_accuracy: 0.7283 - val_loss: 0.6244 - val_binary_accuracy: 0.7273
# Epoch 8/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.6192 - binary_accuracy: 0.7287 - val_loss: 0.6149 - val_binary_accuracy: 0.7261
# Epoch 9/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.6096 - binary_accuracy: 0.7297 - val_loss: 0.6049 - val_binary_accuracy: 0.7298
# Epoch 10/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.6011 - binary_accuracy: 0.7290 - val_loss: 0.5968 - val_binary_accuracy: 0.7288
# Epoch 11/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.5934 - binary_accuracy: 0.7280 - val_loss: 0.5892 - val_binary_accuracy: 0.7290
# Epoch 12/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5860 - binary_accuracy: 0.7286 - val_loss: 0.5828 - val_binary_accuracy: 0.7283
# Epoch 13/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5795 - binary_accuracy: 0.7277 - val_loss: 0.5760 - val_binary_accuracy: 0.7293
# Epoch 14/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5732 - binary_accuracy: 0.7279 - val_loss: 0.5717 - val_binary_accuracy: 0.7253
# Epoch 15/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5671 - binary_accuracy: 0.7274 - val_loss: 0.5650 - val_binary_accuracy: 0.7294
# Epoch 16/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5615 - binary_accuracy: 0.7277 - val_loss: 0.5590 - val_binary_accuracy: 0.7269
# Epoch 17/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5564 - binary_accuracy: 0.7287 - val_loss: 0.5551 - val_binary_accuracy: 0.7247
# Epoch 18/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5517 - binary_accuracy: 0.7285 - val_loss: 0.5508 - val_binary_accuracy: 0.7246
# Epoch 19/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5472 - binary_accuracy: 0.7275 - val_loss: 0.5455 - val_binary_accuracy: 0.7293
# Epoch 20/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5431 - binary_accuracy: 0.7272 - val_loss: 0.5411 - val_binary_accuracy: 0.7258
# Epoch 21/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5391 - binary_accuracy: 0.7274 - val_loss: 0.5377 - val_binary_accuracy: 0.7267
# Epoch 22/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5353 - binary_accuracy: 0.7268 - val_loss: 0.5340 - val_binary_accuracy: 0.7295
# Epoch 23/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5316 - binary_accuracy: 0.7269 - val_loss: 0.5303 - val_binary_accuracy: 0.7284
# Epoch 24/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5282 - binary_accuracy: 0.7275 - val_loss: 0.5317 - val_binary_accuracy: 0.7192
# Epoch 25/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5253 - binary_accuracy: 0.7261 - val_loss: 0.5239 - val_binary_accuracy: 0.7238
# Epoch 26/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5221 - binary_accuracy: 0.7258 - val_loss: 0.5203 - val_binary_accuracy: 0.7256
# Epoch 27/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5187 - binary_accuracy: 0.7270 - val_loss: 0.5182 - val_binary_accuracy: 0.7256
# Epoch 28/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5153 - binary_accuracy: 0.7271 - val_loss: 0.5146 - val_binary_accuracy: 0.7241
# Epoch 29/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5122 - binary_accuracy: 0.7269 - val_loss: 0.5120 - val_binary_accuracy: 0.7280
# Epoch 30/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5094 - binary_accuracy: 0.7272 - val_loss: 0.5094 - val_binary_accuracy: 0.7242
# Epoch 31/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5074 - binary_accuracy: 0.7250 - val_loss: 0.5062 - val_binary_accuracy: 0.7224
# Epoch 32/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5042 - binary_accuracy: 0.7272 - val_loss: 0.5035 - val_binary_accuracy: 0.7252
# Epoch 33/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.5016 - binary_accuracy: 0.7266 - val_loss: 0.5005 - val_binary_accuracy: 0.7255
# Epoch 34/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4991 - binary_accuracy: 0.7264 - val_loss: 0.4979 - val_binary_accuracy: 0.7246
# Epoch 35/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4967 - binary_accuracy: 0.7261 - val_loss: 0.4961 - val_binary_accuracy: 0.7223
# Epoch 36/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4943 - binary_accuracy: 0.7264 - val_loss: 0.4945 - val_binary_accuracy: 0.7237
# Epoch 37/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4922 - binary_accuracy: 0.7259 - val_loss: 0.4917 - val_binary_accuracy: 0.7272
# Epoch 38/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4899 - binary_accuracy: 0.7264 - val_loss: 0.4900 - val_binary_accuracy: 0.7232
# Epoch 39/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4879 - binary_accuracy: 0.7269 - val_loss: 0.4909 - val_binary_accuracy: 0.7206
# Epoch 40/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4861 - binary_accuracy: 0.7269 - val_loss: 0.4848 - val_binary_accuracy: 0.7266
# Epoch 41/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4837 - binary_accuracy: 0.7252 - val_loss: 0.4829 - val_binary_accuracy: 0.7262
# Epoch 42/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4816 - binary_accuracy: 0.7260 - val_loss: 0.4819 - val_binary_accuracy: 0.7236
# Epoch 43/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4797 - binary_accuracy: 0.7271 - val_loss: 0.4804 - val_binary_accuracy: 0.7224
# Epoch 44/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4778 - binary_accuracy: 0.7254 - val_loss: 0.4774 - val_binary_accuracy: 0.7277
# Epoch 45/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4761 - binary_accuracy: 0.7262 - val_loss: 0.4757 - val_binary_accuracy: 0.7275
# Epoch 46/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4742 - binary_accuracy: 0.7261 - val_loss: 0.4736 - val_binary_accuracy: 0.7255
# Epoch 47/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4725 - binary_accuracy: 0.7258 - val_loss: 0.4720 - val_binary_accuracy: 0.7273
# Epoch 48/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4709 - binary_accuracy: 0.7268 - val_loss: 0.4702 - val_binary_accuracy: 0.7262
# Epoch 49/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4694 - binary_accuracy: 0.7257 - val_loss: 0.4688 - val_binary_accuracy: 0.7270
# Epoch 50/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4672 - binary_accuracy: 0.7254 - val_loss: 0.4670 - val_binary_accuracy: 0.7254
# Epoch 51/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4662 - binary_accuracy: 0.7255 - val_loss: 0.4665 - val_binary_accuracy: 0.7244
# Epoch 52/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4649 - binary_accuracy: 0.7257 - val_loss: 0.4658 - val_binary_accuracy: 0.7231
# Epoch 53/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4633 - binary_accuracy: 0.7275 - val_loss: 0.4649 - val_binary_accuracy: 0.7281
# Epoch 54/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4618 - binary_accuracy: 0.7266 - val_loss: 0.4616 - val_binary_accuracy: 0.7285
# Epoch 55/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4603 - binary_accuracy: 0.7259 - val_loss: 0.4609 - val_binary_accuracy: 0.7254
# Epoch 56/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4592 - binary_accuracy: 0.7250 - val_loss: 0.4625 - val_binary_accuracy: 0.7222
# Epoch 57/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4582 - binary_accuracy: 0.7254 - val_loss: 0.4580 - val_binary_accuracy: 0.7254
# Epoch 58/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4567 - binary_accuracy: 0.7245 - val_loss: 0.4582 - val_binary_accuracy: 0.7274
# Epoch 59/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4553 - binary_accuracy: 0.7252 - val_loss: 0.4547 - val_binary_accuracy: 0.7282
# Epoch 60/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4543 - binary_accuracy: 0.7261 - val_loss: 0.4542 - val_binary_accuracy: 0.7270
# Epoch 61/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4526 - binary_accuracy: 0.7264 - val_loss: 0.4526 - val_binary_accuracy: 0.7275
# Epoch 62/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4520 - binary_accuracy: 0.7263 - val_loss: 0.4514 - val_binary_accuracy: 0.7246
# Epoch 63/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4505 - binary_accuracy: 0.7258 - val_loss: 0.4507 - val_binary_accuracy: 0.7249
# Epoch 64/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4493 - binary_accuracy: 0.7265 - val_loss: 0.4499 - val_binary_accuracy: 0.7244
# Epoch 65/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4483 - binary_accuracy: 0.7263 - val_loss: 0.4481 - val_binary_accuracy: 0.7258
# Epoch 66/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4473 - binary_accuracy: 0.7255 - val_loss: 0.4469 - val_binary_accuracy: 0.7241
# Epoch 67/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4463 - binary_accuracy: 0.7265 - val_loss: 0.4464 - val_binary_accuracy: 0.7264
# Epoch 68/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4452 - binary_accuracy: 0.7275 - val_loss: 0.4464 - val_binary_accuracy: 0.7291
# Epoch 69/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4442 - binary_accuracy: 0.7257 - val_loss: 0.4440 - val_binary_accuracy: 0.7256
# Epoch 70/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4432 - binary_accuracy: 0.7271 - val_loss: 0.4436 - val_binary_accuracy: 0.7252
# Epoch 71/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4431 - binary_accuracy: 0.7264 - val_loss: 0.4436 - val_binary_accuracy: 0.7239
# Epoch 72/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4425 - binary_accuracy: 0.7239 - val_loss: 0.4422 - val_binary_accuracy: 0.7255
# Epoch 73/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4410 - binary_accuracy: 0.7237 - val_loss: 0.4510 - val_binary_accuracy: 0.7158
# Epoch 74/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4408 - binary_accuracy: 0.7236 - val_loss: 0.4411 - val_binary_accuracy: 0.7271
# Epoch 75/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4390 - binary_accuracy: 0.7277 - val_loss: 0.4401 - val_binary_accuracy: 0.7262
# Epoch 76/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4389 - binary_accuracy: 0.7231 - val_loss: 0.4387 - val_binary_accuracy: 0.7231
# Epoch 77/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4376 - binary_accuracy: 0.7251 - val_loss: 0.4373 - val_binary_accuracy: 0.7270
# Epoch 78/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4373 - binary_accuracy: 0.7242 - val_loss: 0.4378 - val_binary_accuracy: 0.7274
# Epoch 79/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4366 - binary_accuracy: 0.7259 - val_loss: 0.4384 - val_binary_accuracy: 0.7230
# Epoch 80/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4351 - binary_accuracy: 0.7255 - val_loss: 0.4362 - val_binary_accuracy: 0.7266
# Epoch 81/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4350 - binary_accuracy: 0.7267 - val_loss: 0.4349 - val_binary_accuracy: 0.7275
# Epoch 82/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4334 - binary_accuracy: 0.7255 - val_loss: 0.4351 - val_binary_accuracy: 0.7266
# Epoch 83/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4336 - binary_accuracy: 0.7256 - val_loss: 0.4336 - val_binary_accuracy: 0.7255
# Epoch 84/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4327 - binary_accuracy: 0.7250 - val_loss: 0.4333 - val_binary_accuracy: 0.7257
# Epoch 85/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4318 - binary_accuracy: 0.7234 - val_loss: 0.4343 - val_binary_accuracy: 0.7269
# Epoch 86/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4319 - binary_accuracy: 0.7248 - val_loss: 0.4317 - val_binary_accuracy: 0.7247
# Epoch 87/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4308 - binary_accuracy: 0.7251 - val_loss: 0.4321 - val_binary_accuracy: 0.7230
# Epoch 88/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4303 - binary_accuracy: 0.7234 - val_loss: 0.4308 - val_binary_accuracy: 0.7252
# Epoch 89/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4294 - binary_accuracy: 0.7254 - val_loss: 0.4298 - val_binary_accuracy: 0.7264
# Epoch 90/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4283 - binary_accuracy: 0.7260 - val_loss: 0.4306 - val_binary_accuracy: 0.7259
# Epoch 91/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4285 - binary_accuracy: 0.7246 - val_loss: 0.4310 - val_binary_accuracy: 0.7221
# Epoch 92/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4284 - binary_accuracy: 0.7252 - val_loss: 0.4281 - val_binary_accuracy: 0.7245
# Epoch 93/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4270 - binary_accuracy: 0.7260 - val_loss: 0.4285 - val_binary_accuracy: 0.7270
# Epoch 94/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4264 - binary_accuracy: 0.7262 - val_loss: 0.4293 - val_binary_accuracy: 0.7267
# Epoch 95/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4259 - binary_accuracy: 0.7254 - val_loss: 0.4262 - val_binary_accuracy: 0.7250
# Epoch 96/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4257 - binary_accuracy: 0.7248 - val_loss: 0.4261 - val_binary_accuracy: 0.7247
# Epoch 97/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4248 - binary_accuracy: 0.7259 - val_loss: 0.4264 - val_binary_accuracy: 0.7285
# Epoch 98/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4244 - binary_accuracy: 0.7262 - val_loss: 0.4262 - val_binary_accuracy: 0.7265
# Epoch 99/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4246 - binary_accuracy: 0.7243 - val_loss: 0.4263 - val_binary_accuracy: 0.7236
# Epoch 100/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4237 - binary_accuracy: 0.7235 - val_loss: 0.4248 - val_binary_accuracy: 0.7236
# Epoch 101/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4233 - binary_accuracy: 0.7264 - val_loss: 0.4235 - val_binary_accuracy: 0.7297
# Epoch 102/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4226 - binary_accuracy: 0.7250 - val_loss: 0.4230 - val_binary_accuracy: 0.7255
# Epoch 103/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4220 - binary_accuracy: 0.7248 - val_loss: 0.4227 - val_binary_accuracy: 0.7251
# Epoch 104/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4214 - binary_accuracy: 0.7261 - val_loss: 0.4228 - val_binary_accuracy: 0.7248
# Epoch 105/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4216 - binary_accuracy: 0.7263 - val_loss: 0.4254 - val_binary_accuracy: 0.7207
# Epoch 106/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4214 - binary_accuracy: 0.7229 - val_loss: 0.4215 - val_binary_accuracy: 0.7249
# Epoch 107/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4208 - binary_accuracy: 0.7235 - val_loss: 0.4213 - val_binary_accuracy: 0.7274
# Epoch 108/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4208 - binary_accuracy: 0.7239 - val_loss: 0.4207 - val_binary_accuracy: 0.7261
# Epoch 109/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4202 - binary_accuracy: 0.7259 - val_loss: 0.4206 - val_binary_accuracy: 0.7247
# Epoch 110/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4200 - binary_accuracy: 0.7264 - val_loss: 0.4238 - val_binary_accuracy: 0.7205
# Epoch 111/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4188 - binary_accuracy: 0.7279 - val_loss: 0.4203 - val_binary_accuracy: 0.7286
# Epoch 112/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4186 - binary_accuracy: 0.7254 - val_loss: 0.4210 - val_binary_accuracy: 0.7247
# Epoch 113/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4182 - binary_accuracy: 0.7278 - val_loss: 0.4195 - val_binary_accuracy: 0.7284
# Epoch 114/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4185 - binary_accuracy: 0.7243 - val_loss: 0.4184 - val_binary_accuracy: 0.7245
# Epoch 115/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4182 - binary_accuracy: 0.7257 - val_loss: 0.4191 - val_binary_accuracy: 0.7232
# Epoch 116/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4174 - binary_accuracy: 0.7252 - val_loss: 0.4182 - val_binary_accuracy: 0.7272
# Epoch 117/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4180 - binary_accuracy: 0.7249 - val_loss: 0.4175 - val_binary_accuracy: 0.7242
# Epoch 118/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4166 - binary_accuracy: 0.7235 - val_loss: 0.4184 - val_binary_accuracy: 0.7227
# Epoch 119/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4166 - binary_accuracy: 0.7264 - val_loss: 0.4170 - val_binary_accuracy: 0.7247
# Epoch 120/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4162 - binary_accuracy: 0.7247 - val_loss: 0.4166 - val_binary_accuracy: 0.7256
# Epoch 121/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4158 - binary_accuracy: 0.7241 - val_loss: 0.4170 - val_binary_accuracy: 0.7246
# Epoch 122/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4150 - binary_accuracy: 0.7263 - val_loss: 0.4170 - val_binary_accuracy: 0.7286
# Epoch 123/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4149 - binary_accuracy: 0.7255 - val_loss: 0.4156 - val_binary_accuracy: 0.7259
# Epoch 124/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4150 - binary_accuracy: 0.7257 - val_loss: 0.4167 - val_binary_accuracy: 0.7265
# Epoch 125/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4145 - binary_accuracy: 0.7271 - val_loss: 0.4167 - val_binary_accuracy: 0.7256
# Epoch 126/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4146 - binary_accuracy: 0.7236 - val_loss: 0.4145 - val_binary_accuracy: 0.7276
# Epoch 127/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4141 - binary_accuracy: 0.7241 - val_loss: 0.4146 - val_binary_accuracy: 0.7248
# Epoch 128/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4138 - binary_accuracy: 0.7231 - val_loss: 0.4143 - val_binary_accuracy: 0.7259
# Epoch 129/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4135 - binary_accuracy: 0.7259 - val_loss: 0.4145 - val_binary_accuracy: 0.7259
# Epoch 130/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4135 - binary_accuracy: 0.7229 - val_loss: 0.4154 - val_binary_accuracy: 0.7217
# Epoch 131/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4131 - binary_accuracy: 0.7256 - val_loss: 0.4153 - val_binary_accuracy: 0.7258
# Epoch 132/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4132 - binary_accuracy: 0.7250 - val_loss: 0.4139 - val_binary_accuracy: 0.7233
# Epoch 133/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4126 - binary_accuracy: 0.7241 - val_loss: 0.4131 - val_binary_accuracy: 0.7251
# Epoch 134/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4120 - binary_accuracy: 0.7264 - val_loss: 0.4148 - val_binary_accuracy: 0.7300
# Epoch 135/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4121 - binary_accuracy: 0.7249 - val_loss: 0.4132 - val_binary_accuracy: 0.7255
# Epoch 136/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4118 - binary_accuracy: 0.7247 - val_loss: 0.4126 - val_binary_accuracy: 0.7224
# Epoch 137/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4111 - binary_accuracy: 0.7249 - val_loss: 0.4134 - val_binary_accuracy: 0.7259
# Epoch 138/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4111 - binary_accuracy: 0.7252 - val_loss: 0.4117 - val_binary_accuracy: 0.7253
# Epoch 139/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4109 - binary_accuracy: 0.7242 - val_loss: 0.4117 - val_binary_accuracy: 0.7252
# Epoch 140/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4112 - binary_accuracy: 0.7264 - val_loss: 0.4114 - val_binary_accuracy: 0.7297
# Epoch 141/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4105 - binary_accuracy: 0.7255 - val_loss: 0.4113 - val_binary_accuracy: 0.7261
# Epoch 142/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4119 - binary_accuracy: 0.7242 - val_loss: 0.4106 - val_binary_accuracy: 0.7236
# Epoch 143/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4119 - binary_accuracy: 0.7247 - val_loss: 0.4105 - val_binary_accuracy: 0.7242
# Epoch 144/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4106 - binary_accuracy: 0.7246 - val_loss: 0.4102 - val_binary_accuracy: 0.7236
# Epoch 145/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4093 - binary_accuracy: 0.7247 - val_loss: 0.4098 - val_binary_accuracy: 0.7249
# Epoch 146/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4092 - binary_accuracy: 0.7249 - val_loss: 0.4100 - val_binary_accuracy: 0.7300
# Epoch 147/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4103 - binary_accuracy: 0.7256 - val_loss: 0.4102 - val_binary_accuracy: 0.7263
# Epoch 148/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4090 - binary_accuracy: 0.7263 - val_loss: 0.4101 - val_binary_accuracy: 0.7279
# Epoch 149/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4088 - binary_accuracy: 0.7250 - val_loss: 0.4100 - val_binary_accuracy: 0.7294
# Epoch 150/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4086 - binary_accuracy: 0.7267 - val_loss: 0.4089 - val_binary_accuracy: 0.7252
# Epoch 151/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4084 - binary_accuracy: 0.7270 - val_loss: 0.4090 - val_binary_accuracy: 0.7245
# Epoch 152/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4081 - binary_accuracy: 0.7265 - val_loss: 0.4122 - val_binary_accuracy: 0.7204
# Epoch 153/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4095 - binary_accuracy: 0.7260 - val_loss: 0.4093 - val_binary_accuracy: 0.7245
# Epoch 154/200
# 96/96 [==============================] - 2s 23ms/step - loss: 0.4077 - binary_accuracy: 0.7260 - val_loss: 0.4113 - val_binary_accuracy: 0.7199
# Epoch 155/200
# 96/96 [==============================] - 2s 22ms/step - loss: 0.4075 - binary_accuracy: 0.7260 - val_loss: 0.4092 - val_binary_accuracy: 0.7266

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
y_pred = model.predict(X_valid).round()
# Out:
# 657/657 [==============================] - 1s 1ms/step

# %%
#pip install tensorflow-addons

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
conf_matrix = confusion_matrix(y_true=y_valid, y_pred=y_pred)
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
print(f"f1_score is:{f1_score(y_valid, y_pred, average='binary')}\n accuracy_score is: {accuracy_score(y_valid, y_pred)}\n precision is: {precision_score(y_valid, y_pred)}\n recal is: {recall_score(y_valid, y_pred)}")
# Out:
# f1_score is:0.7439613526570048
#  accuracy_score is: 0.725218797564688
#  precision is: 0.6964567255829391
#  recal is: 0.7984208523592086
